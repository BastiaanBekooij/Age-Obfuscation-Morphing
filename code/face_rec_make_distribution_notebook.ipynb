# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Jan  7 15:06:32 2021

@author: murie
"""

import numpy as np
import pandas as pd
#%matplotlib inline
import matplotlib.pyplot as plt 
  
#f = open('C:/Users/murie/Documents/school/master/1B/Introduction2Biometrics/project_git/data/before_rec_other_v2_csv.txt', 'r')
f = open('../data/before_rec_csv', 'r')
data = []
dist2self = []
dist2otherNE = []
dist2otherE = []
other = []

for i in f:
    #print(i)
    data = i.split(';')
    print(data)
    #other.append(float(data[0]))
    dist2self.append(float(data[0]))
    dist2otherNE.append(float(data[1]))
    #dist2otherE.append(float(data[2]))
    f.close

print(type(other))
#print(type(dist2self))
#[float(i) for i in dist2self]
#print(type(dist2self))
#gym = pd.DataFrame({'Distance to self': dist2self, 'Distance to other (no expression)': dist2otherNE})
#gym.plot.hist(bins = 40, alpha=0.5)

bins = np.arange(-10, 35, 2) #left margin, right margin, step size (years)
plt.figure(figsize=(5,2.5), dpi=160)
plt.gcf()#.subplots_adjust(bottom=0.20)
plt.show() 

#bins = np.arange(-10, 35, 2) #left margin, right margin, step size (years)
#plt.figure(figsize=(5,2.5), dpi=160)
#plt.gcf().subplots_adjust(bottom=0.20)
# Out:
# ['0.258227848', ' 0.896868012', ' 0.881517527\n']
# ['0.116128191', ' 0.884501209', ' 0.865515193\n']
# ['0.13036533', ' 0.882232164', ' 0.910819814\n']
# ['0.289375742', ' 0.477112336', ' 0.498938729\n']
# ['0.136331155', ' 0.670438464', ' 0.615967155\n']
# ['0.247946803', ' 0.586243858', ' 0.627310779\n']
# ['0.20879653', ' 0.730141388', ' 0.647583354\n']
# ['0.347756163', ' 0.601682535', ' 0.660282754\n']
# ['0.280907892', ' 0.698939677', ' 0.662214436\n']
# ['0.179693324', ' 0.662471211', ' 0.629867829\n']
# ['0.18039841', ' 0.511056108', ' 0.575037855\n']
# ['0.224325479', ' 0.776180244', ' 0.739993132\n']
# ['0.275442668', ' 0.497438071', ' 0.578930543\n']
# ['0.325963466', ' 0.771987636', ' 0.788722844\n']
# ['0.131017805', ' 0.632902549', ' 0.677123476\n']
# ['0.199613515', ' 0.728452494', ' 0.718234607\n']
# ['0.2247343', ' 0.441690913', ' 0.476316184\n']
# ['0.247205028', ' 0.85683209', ' 0.830753838\n']
# ['0.182423518', ' 0.413464348', ' 0.415896716\n']
# ['0.0906531', ' 0.691017185', ' 0.714746646\n']
# ['0.309393323', ' 0.81772705', ' 0.816754474\n']
# ['0.191376764', ' 0.782494356', ' 0.795627788\n']
# ['0.181976284', ' 0.602430053', ' 0.60598598\n']
# ['0.11722805', ' 0.884055728', ' 0.876142109\n']
# ['0.255954161', ' 0.758510539', ' 0.79675255\n']
# ['0.154891583', ' 0.60253256', ' 0.606450557\n']
# ['0.078822192', ' 0.695429793', ' 0.712978809\n']
# ['0.220324543', ' 0.458307471', ' 0.475144641\n']
# ['0.234794602', ' 0.667187243', ' 0.675305707\n']
# ['0.181176278', ' 0.805005015', ' 0.795460947\n']
# ['0.288133862', ' 0.665950861', ' 0.703337732\n']
# ['0.298681916', ' 0.734537486', ' 0.727114713\n']
# ['0.145505004', ' 0.768301815', ' 0.827035548\n']
# ['0.349540214', ' 0.792079183', ' 0.78867864\n']
# ['0.117022708', ' 0.815009536', ' 0.814944893\n']
# ['0.203042681', ' 0.582067138', ' 0.631716098\n']
# ['0.207358606', ' 0.686564128', ' 0.737857684\n']
# ['0.242697765', ' 0.804940422', ' 0.821563382\n']
# ['0.130054891', ' 0.734688609', ' 0.71080275\n']
# ['0.292115889', ' 0.758158103', ' 0.785212322\n']
# ['0.207309107', ' 0.756455209', ' 0.791589901\n']
# ['0.269408738', ' 0.709093044', ' 0.757499822\n']
# ['0.264429232', ' 0.780401329', ' 0.783369921\n']
# ['0.172421946', ' 0.815859623', ' 0.799945514\n']
# ['0.13717123', ' 0.761595123', ' 0.742151923\n']
# ['0.198305696', ' 0.793754981', ' 0.788425627\n']
# ['0.169716259', ' 0.7732987', ' 0.767232808\n']
# ['0.169279334', ' 0.716402686', ' 0.723979677\n']
# ['0.139095189', ' 0.8193139', ' 0.840769379\n']
# ['0.120051701', ' 0.636785498', ' 0.653572756\n']
# ['0.12715552', ' 0.717372614', ' 0.712436345\n']
# ['0.311217374', ' 0.68036859', ' 0.774152816\n']
# ['0.247680953', ' 0.647681655', ' 0.655919992\n']
# ['0.207880551', ' 0.734938507', ' 0.732594262\n']
# ['0.176606938', ' 0.723389355', ' 0.723338603\n']
# ['0.176003567', ' 0.764567659', ' 0.787003539\n']
# ['0.181902743', ' 0.852052322', ' 0.815393019\n']
# ['0.195964422', ' 0.741003846', ' 0.732178186\n']
# ['0.149652717', ' 0.84117744', ' 0.842125572\n']
# ['0.21458911', ' 0.638142662', ' 0.655963567\n']
# ['0.251954181', ' 0.801558099', ' 0.7910589\n']
# ['0.065787294', ' 0.662390721', ' 0.620777538\n']
# ['0.169058896', ' 0.88636564', ' 0.911014641\n']
# ['0.216930701', ' 0.705894645', ' 0.709430388\n']
# ['0.215908344', ' 0.772798929', ' 0.802167837\n']
# ['0.250778063', ' 0.699067031', ' 0.69677021\n']
# ['0.329265562', ' 0.573395961', ' 0.607841816\n']
# ['0.248586778', ' 0.8847078', ' 0.895117778\n']
# ['0.2850625', ' 0.763035299', ' 0.746937206\n']
# ['0.151563291', ' 0.756158975', ' 0.735640304\n']
# ['0.196663144', ' 0.648176755', ' 0.641866746\n']
# ['0.217894286', ' 0.659135038', ' 0.659989428\n']
# ['0.244664863', ' 0.722713327', ' 0.712168859\n']
# ['0.29782284', ' 0.768197754', ' 0.788661963\n']
# ['0.140528569', ' 0.705234715', ' 0.687005197\n']
# ['0.214686101', ' 0.670317281', ' 0.669580265\n']
# ['0.226453226', ' 0.744630357', ' 0.709740614\n']
# ['0.248464507', ' 0.614302649', ' 0.598688983\n']
# ['0.228393354', ' 0.762376305', ' 0.773504035\n']
# ['0.181470459', ' 0.835105358', ' 0.845229115\n']
# ['0.088591764', ' 0.879635152', ' 0.856281873\n']
# ['0.22558368', ' 0.779021904', ' 0.775532392\n']
# ['0.135517598', ' 0.584804514', ' 0.599411591\n']
# ['0.216000843', ' 0.912080599', ' 0.903665738\n']
# ['0.215384453', ' 0.729266647', ' 0.685769526\n']
# ['0.195951259', ' 0.821669214', ' 0.81778922\n']
# ['0.254014014', ' 0.797587575', ' 0.789092505\n']
# ['0.197435882', ' 0.843848995', ' 0.842350735\n']
# ['0.1970844', ' 0.666543606', ' 0.682570841\n']
# ['0.245799588', ' 0.751751926', ' 0.751085309\n']
# ['0.289165662', ' 0.488969561', ' 0.51426149\n']
# ['0.23279072', ' 0.651639593', ' 0.656597604\n']
# ['0.376907229', ' 0.606427342', ' 0.628870151\n']
# ['0.333369622', ' 0.781933746', ' 0.780595576\n']
# ['0.1862211', ' 0.677273327', ' 0.687550505\n']
# ['0.231058866', ' 0.769768402', ' 0.764892129\n']
# ['0.141752633', ' 0.784915691', ' 0.788621954\n']
# ['0.142789347', ' 0.673532145', ' 0.647601398\n']
# ['0.105733262', ' 0.688867353', ' 0.663295033\n']
# ['0.238721742', ' 0.646464681', ' 0.63540766\n']
# ['0.36025775', ' 0.783629762', ' 0.823528222\n']
# ['0.12956343', ' 0.655441095', ' 0.652512179\n']
# ['0.133912107', ' 0.776160586', ' 0.739051509\n']
# ['0.286263886', ' 0.713803238', ' 0.718800011\n']
# ['0.156649109', ' 0.714747385', ' 0.724045514\n']
# ['0.211790217', ' 0.628532013', ' 0.635373201\n']
# ['0.257854608', ' 0.917392892', ' 0.887882665\n']
# ['0.191857136', ' 0.893684955', ' 0.854057688\n']
# ['0.263173504', ' 0.795733103', ' 0.794573776\n']
# ['0.297853727', ' 0.787351751', ' 0.770900032\n']
# ['0.20685811', ' 0.737279476', ' 0.742322335\n']
# ['0.14494246', ' 0.807294231', ' 0.780783713\n']
# ['0.205440048', ' 0.751671514', ' 0.767692654\n']
# ['0.1371464', ' 0.853573917', ' 0.856424756\n']
# <class 'list'>
